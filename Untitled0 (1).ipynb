# %%
#Crear las carpetas para subir las imagenes
# !mkdir Cuchillos
# !mkdir Cucharas
# !mkdir Tenedores
# Out:
# mkdir: cannot create directory ‘Cuchillos’: File exists
# mkdir: cannot create directory ‘Cucharas’: File exists
# mkdir: cannot create directory ‘Tenedores’: File exists

# %%
# Entrar en cada carpeta y descomprimir el archivo zip
# %cd Cuchillos
# !unzip "Cuchillos  (1).zip"
# !rm "Cuchillos  (1).zip"
# %cd ..

# %cd Tenedores
# !unzip Tenedores.zip
# %cd ..

# %cd Cucharas
# !unzip Cucharas.zip
# %cd ..
# Out:
# /content/Cuchillos
# Archive:  Cuchillos  (1).zip
#  extracting: image.png
#  extracting: image (1).png
#  extracting: image (2).png
#  extracting: image (3).png
#  extracting: image (4).png
#  extracting: image (5).png
#  extracting: image (6).png
#  extracting: image (7).png
#  extracting: image (8).png
#  extracting: empty-light-2x.png
#  extracting: empty-dark-2x.png
#  extracting: al-icon.png
#  extracting: GAS0702010005374_1_1_2.png
#  extracting: 78605.png
#  extracting: Humvee-Daga-Portada.png
#  extracting: termalimex-5.png
#  extracting: 410901663_1000x1000.png
#  extracting: Cuchillo_de_sushi-removebg-preview.png
#  extracting: PAGINA-WEB-7.png
#  extracting: Tactical-Capm-Field-Knife-2.png
#  extracting: Professional_Serrated_knife_9-inch_3.png.txt
#  extracting: cuchillo1-1-300x300.png
#  extracting: 4Messer_-fcm-.png
#  extracting: 1000.png
#  extracting: 9HQ4H3Rxu4Wc_67KElhBvjNx3n85sBt1Gi-NMyjgqxCcpLIu3KBXmoWyafIj.png
#  extracting: Copia_de_Sin_t_tulo_4__4.png.txt
# /content
# /content/Tenedores
# unzip:  cannot find or open Tenedores.zip, Tenedores.zip.zip or Tenedores.zip.ZIP.
# /content
# /content/Cucharas
# unzip:  cannot find or open Cucharas.zip, Cucharas.zip.zip or Cucharas.zip.ZIP.
# /content

# %%
#Borrar los archivo ZIP
# !rm -rf /content/Cucharas/Cucharas.zip
# !rm -rf /content/Tenedores/Tenedores.zip
# /content/Cucharas/Cucharas

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/Cucharas | wc -l
# !ls /content/Cuchillos | wc -l
# !ls /content/Tenedores | wc -l
# Out:
# 157
# 1
# 162

# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/Cuchillos'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  try:
    imagen = mpimg.imread(os.path.join(carpeta, nombreimg))
    plt.imshow(imagen)
  except:
    pass
